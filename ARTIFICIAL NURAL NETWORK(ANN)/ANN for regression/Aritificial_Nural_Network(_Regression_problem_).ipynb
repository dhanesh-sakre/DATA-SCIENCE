# %% [markdown]
# # ANN

# %%
# installing tensorflow liberary
# !pip install tensorflow

# %%
# installing necessary liberaries
# for data manupulation
import pandas as pd
import numpy as np

# for data visualization
import seaborn as sns
import matplotlib.pyplot as plt
# setting parameters for graphs
plt.rcParams['figure.figsize']  = (10, 5)
plt.rcParams['figure.dpi']  = 250

# for model and data preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import r2_score

# for ignoring future warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# reading dataset
df = pd.read_csv('https://raw.githubusercontent.com/dhanesh-sakre/DATA-SCIENCE/refs/heads/main/ARTIFICIAL%20NURAL%20NETWORK(ANN)/ANN%20for%20regression/Regression.csv')
df
# Out:
#           price     feature1     feature2
# 0    461.527929   999.787558   999.766096
# 1    548.130012   998.861615  1001.042403
# 2    410.297162  1000.070267   998.844015
# 3    540.382220   999.952251  1000.440940
# 4    546.024553  1000.446011  1000.338531
# ..          ...          ...          ...
# 995  476.526078  1000.018988   999.672732
# 996  457.313186   998.855379  1000.020026
# 997  456.720993  1001.451646   998.847605
# 998  403.315576  1000.771023   998.562851
# 999  599.367094   999.232244  1001.451407
#
# [1000 rows x 3 columns]

# %%
df.nunique()
# Out:
# price       1000
# feature1    1000
# feature2    1000
# dtype: int64

# %%
df.head()
# Out:
#         price     feature1     feature2
# 0  461.527929   999.787558   999.766096
# 1  548.130012   998.861615  1001.042403
# 2  410.297162  1000.070267   998.844015
# 3  540.382220   999.952251  1000.440940
# 4  546.024553  1000.446011  1000.338531

# %%
# checking null values
df.isna().sum()
# Out:
# price       0
# feature1    0
# feature2    0
# dtype: int64

# %%
# no missing values

# %%
# checking duplicated values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # model building part

# %%
# defining x and y variable

x = df.iloc[:,1:]
y = df['price']

# %%
# feature scalling(standardization)
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[-0.32622142,  0.29351742, -1.04175968, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        [-0.44003595,  0.19816383, -1.38753759, ...,  1.74273971,
#          1.09598752, -1.09598752],
#        [-1.53679418,  0.29351742,  1.03290776, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        ...,
#        [ 0.60498839, -0.27860412,  0.68712986, ..., -0.57380915,
#          1.09598752, -1.09598752],
#        [ 1.25683526,  0.29351742, -0.69598177, ..., -0.57380915,
#         -0.91241915,  0.91241915],
#        [ 1.46377078, -1.04143285, -0.35020386, ..., -0.57380915,
#          1.09598752, -1.09598752]])

# %%
# splitting data into training and testing data
xtrain, xtest, ytrain, ytest = train_test_split(x, y, train_size=0.80, random_state=42)

# %%
# model building
ann = Sequential()

ann.add(Dense(units=30, activation='relu'))
ann.add(Dense(units=20, activation='relu'))

ann.add(Dense(units=1))

ann.compile(optimizer='adam', loss='mse')

ann.fit(xtrain, ytrain, epochs=100, validation_data=(xtest, ytest))
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0973 - val_loss: 0.0123
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0092 - val_loss: 0.0054
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - val_loss: 9.8386e-04
# Epoch 8/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.3101e-04 - val_loss: 7.7080e-04
# Epoch 9/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 6.4783e-04 - val_loss: 6.2799e-04
# Epoch 10/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5.0992e-04 - val_loss: 5.1678e-04
# Epoch 11/100
# ...

# %%
# it is showing loss on both the training data as well as testing datas

# %%
# getting prediction
ypred = ann.predict(xtest)
ypred
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[1.0278753e-04],
#        [1.0278753e-04],
#        [6.6320901e-04],
#        ...,
#        [1.0006113e+00],
#        [9.9990571e-01],
#        [1.0005602e+00]], dtype=float32)

# %%
# evaluation of model
r2_score(ytest, ypred)
# Out:
# 0.9999954700469971

# %%
# accuracy of model is 99% on this dataset
