# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 250
plt.rcParams["figure.figsize"]= (15, 8)
# %matplotlib inline

# %%
df = pd.read_csv("Cardiotocographic.csv")

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.tail()
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %% [markdown]
# # Statistical Summary:

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %% [markdown]
# finding from statistical analysis:

# %%
# there are total 2126 rows in this file
# LB, AC, FM, DS, DP, MLTV, Width, Tendency, NSP columns are having missing values
# LB, ASTV, MSTV, ALTV, MLTV, Width may have outliers

# %% [markdown]
# # checking dtatypes of all the columns

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %% [markdown]
# all columns are present in their correct datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.shape     #total row and columns
# Out:
# (2126, 14)

# %% [markdown]
# # checking for the dupliccated records

# %%
df.duplicated().sum()
# Out:
# 2

# %% [markdown]
# there are two duplicated records are present in the data

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (2124, 14)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# # check for deuplicated rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# duplicated rows removed

# %%
df.shape
# Out:
# (2124, 14)

# %%
df.head(10)
# Out:
#            LB        AC   FM        UC        DL   DS        DP  ASTV  MSTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.000000  73.0   0.5
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.000000  17.0   2.1
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.000000  16.0   2.1
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.000000  16.0   2.4
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.000000  16.0   2.4
# 5  134.000000  0.001116  0.0  0.010493  0.009444  0.0  0.002099  26.0   5.9
# 6  134.000000  0.001403  0.0  0.012623  0.008415  0.0  0.002805  29.0   6.3
# 7  122.000000  0.000000  0.0  0.000000  0.000000  0.0  0.000000  83.0   0.5
# 8  122.000000  0.038567  0.0  0.001517  0.000000  0.0  0.000000  84.0   0.5
# 9  122.000000  0.000000  0.0  0.002967  0.000000  0.0  0.000000  86.0   0.3
#
#    ALTV  MLTV       Width  Tendency       NSP
# 0  43.0   2.4   64.000000  0.999926  2.000000
# ...

# %% [markdown]
# # checking the null or missing values

# %%
df.isna().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df.iloc[:,[0,1,5,6,10,11,12,13]]
# Out:
#               LB        AC   DS   DP  MLTV  Width  Tendency       NSP
# 0     120.000000  0.000000  0.0  0.0   2.4   64.0  0.999926  2.000000
# 1     132.000000  0.006380  0.0  0.0  10.4  130.0  0.000000  1.000000
# 2     133.000000  0.003322  0.0  0.0  13.4  130.0  0.000000  1.000000
# 3     134.000000  0.002561  0.0  0.0  23.0  117.0  1.000000  1.000000
# 4     131.948232  0.006515  0.0  0.0  19.9  117.0  1.000000  1.000000
# ...          ...       ...  ...  ...   ...    ...       ...       ...
# 2121  140.000000  0.000000  0.0  0.0   7.2   40.0  0.000000  2.000000
# 2122  140.000000  0.000775  0.0  0.0   7.1   66.0  1.000000  2.000000
# 2123  140.000000  0.000980  0.0  0.0   6.1   67.0  1.000000  1.990464
# 2124  140.000000  0.000679  0.0  0.0   7.0   66.0  1.000000  2.000000
# 2125  142.000000  0.001616  0.0  0.0   5.0   42.0  0.000000  1.000000
#
# [2124 rows x 8 columns]

# %% [markdown]
# # imputing missing values

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy='median')

# %%
df.iloc[:,[0,1,5,6,10,11,12,13]] = si.fit_transform(df.iloc[:,[0,1,5,6,10,11,12,13]])

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
len(df)
# Out:
# 2124

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %% [markdown]
# all the missing values imputed and there is no missing values in any column

# %% [markdown]
# # check for the OUTLIERS

# %%
df.boxplot()
plt.tight_layout()

# %%
df.hist()
plt.tight_layout()

# %% [markdown]
# outliers are present in all columns

# %% [markdown]
# ## Removing Outliers

# %%
df.shape
# Out:
# (2124, 14)

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# # defining the function for outlier removal by using capping method

# %%
def capping(data, columns) :
    for col in columns:
        q1 = data[col].quantile(0.25)
        q3 = data[col].quantile(0.75)
        IQR = q1 - q3
        lower = q1 - (1.5 * IQR)
        upper = q3 + (1.5 * IQR)
        df[col]  = np.where( df[col] > upper, upper,
                            np.where(df[col] < lower, lower,
                                     df[col])
                           )

# %% [markdown]
# calling the functiion to remove outliers from all the columns

# %%
capping(df, df.columns)

# %%
df
# Out:
#          LB        AC        FM       UC        DL   DS   DP  ASTV  MSTV  \
# 0     119.0 -0.002806 -0.001284 -0.00048 -0.001646  0.0  0.0  17.5   0.2
# 1     119.0 -0.002806 -0.001284 -0.00048 -0.001646  0.0  0.0  17.5   0.2
# 2     119.0 -0.002806 -0.001284 -0.00048 -0.001646  0.0  0.0  17.5   0.2
# 3     119.0 -0.002806 -0.001284 -0.00048 -0.001646  0.0  0.0  17.5   0.2
# 4     119.0 -0.002806 -0.001284 -0.00048 -0.001646  0.0  0.0  17.5   0.2
# ...     ...       ...       ...      ...       ...  ...  ...   ...   ...
# 2121  119.0 -0.002806 -0.001284 -0.00048 -0.001646  0.0  0.0  17.5   0.2
# 2122  119.0 -0.002806 -0.001284 -0.00048 -0.001646  0.0  0.0  17.5   0.2
# 2123  119.0 -0.002806 -0.001284 -0.00048 -0.001646  0.0  0.0  17.5   0.2
# 2124  119.0 -0.002806 -0.001284 -0.00048 -0.001646  0.0  0.0  17.5   0.2
# 2125  119.0 -0.002806 -0.001284 -0.00048 -0.001646  0.0  0.0  17.5   0.2
#
#       ALTV  MLTV  Width  Tendency  NSP
# 0     -5.5   1.5    5.5      -0.5  1.0
# ...

# %% [markdown]
# ## the distribution of the data after removing outliers

# %%
df.boxplot()
plt.tight_layout()

# %% [markdown]
# outliers have been removed from all the columns

# %%
df.hist()
plt.tight_layout()

# %% [markdown]
# ### In healthcare industry outliers provide us a crucial information so keeping them as it is can be a good decision. And it completely depends upon the problem statement like what we want to analyse or what problem we are going to solve with the analysis
